# %% [markdown]
# # Table 4
# - Py kernel

# %%
import pandas as pd
import numpy as np
import pingouin as pg

from scipy import stats

# %% [markdown]
# # Load Data

# %%
base = "/Users/brinkley97/Documents/development/lab-kcad/"
path_to_file = "datasets/tiles_dataset/table_4/sleep/"
name_of_file = "sleep.csv.gz"
file = base + path_to_file + name_of_file

# %%
def load_data(file):
    original_data = pd.read_csv(file)
    # original_data = pd.DataFrame(file)
    copy_of_data = original_data.copy()
    return copy_of_data

# %%
sleep_df = load_data(file)
sleep_df
# Out:
#                                Unnamed: 0    duration  efficiency  \
# 0    02581754-36cd-4b23-85ea-bf995c6dec83  320.756410   90.871795
# 1    02581754-36cd-4b23-85ea-bf995c6dec83  277.904762   91.285714
# 2    02581754-36cd-4b23-85ea-bf995c6dec83  370.750000   90.388889
# 3    02b7a595-6508-46bd-8239-6deb433d6290  481.990385   93.769231
# 4    02b7a595-6508-46bd-8239-6deb433d6290  479.941176   94.470588
# ..                                    ...         ...         ...
# 313  fae38580-1e2d-4491-9de5-7b75703ba4ce  401.230769   93.846154
# 314  fae38580-1e2d-4491-9de5-7b75703ba4ce  424.280000   92.760000
# 315  fcb14a4c-1ffa-4315-872a-a38833459885  493.588235   96.279412
# 316  fcb14a4c-1ffa-4315-872a-a38833459885  476.514286   96.542857
# 317  fcb14a4c-1ffa-4315-872a-a38833459885  511.696970   96.000000
#
#      minutesAsleep         mid   mid_std  duration_diff  shift  lang     work  \
# 0        86.540823  363.500000  4.554692         109.75  night     1      all
# 1        85.950135   11.133333       NaN            NaN  night     1  workday
# 2        87.235749    4.166667       NaN            NaN  night     1   offday
# 3        84.791808   66.000000  6.116897          37.50    day     1      all
# 4        85.990243    2.416667       NaN            NaN    day     1  workday
# ..             ...         ...       ...            ...    ...   ...      ...
# 313      86.451948    2.791667       NaN            NaN    day     1  workday
# 314      85.102538    4.550000       NaN            NaN    day     1   offday
# 315      89.868517   21.000000  3.665858          44.00    day     1      all
# 316      89.342715    2.016667       NaN            NaN    day     1  workday
# 317      90.426186    2.350000       NaN            NaN    day     1   offday
#
#      ...  stai  pan_PosAffect pan_NegAffect swls psqi  rand_GeneralHealth  \
# 0    ...    24             47            20  5.4  7.0                75.0
# 1    ...    24             47            20  5.4  7.0                75.0
# 2    ...    24             47            20  5.4  7.0                75.0
# 3    ...    40             32            13  6.0  7.0                85.0
# 4    ...    40             32            13  6.0  7.0                85.0
# ..   ...   ...            ...           ...  ...  ...                 ...
# 313  ...    41             37            16  4.6  9.0                65.0
# 314  ...    41             37            16  4.6  9.0                65.0
# 315  ...    29             34            15  5.6  4.0                40.0
# 316  ...    29             34            15  5.6  4.0                40.0
# 317  ...    29             34            15  5.6  4.0                40.0
#
#      rand_EnergyFatigue  total_seconds  mean_seconds  frequency
# 0                  75.0            NaN           NaN        NaN
# 1                  75.0            NaN           NaN        NaN
# 2                  75.0            NaN           NaN        NaN
# 3                  60.0            NaN           NaN        NaN
# 4                  60.0            NaN           NaN        NaN
# ..                  ...            ...           ...        ...
# 313                70.0            NaN           NaN        NaN
# 314                70.0            NaN           NaN        NaN
# 315                45.0            NaN           NaN        NaN
# 316                45.0            NaN           NaN        NaN
# 317                45.0            NaN           NaN        NaN
#
# [318 rows x 25 columns]

# %% [markdown]
# # Load Generated Specific Questions

# %%
base = "/Users/brinkley97/Documents/development/lab-kcad/"
path_to_questions = "tiles-day-night/my_code/"
name_of_questions = "generateSpecificQuestions.ipynb"
questions = base + path_to_questions + name_of_questions

# %%
# %load questions
/Users/brinkley97/Documents/development/lab-kcad/tiles-day-night/my_codegenerateSpecificQuestions.ipynb

# %%
# %run "generateSpecificQuestions.ipynb"
